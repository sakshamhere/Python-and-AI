# %%
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown,display

# %%
                                                # Step 1: When working with OpenAI key we will need to load key which will be saved in .env file

# load_dotenv(override=True)
# api_key = os.getenv('OPENAI_API_KEY')

                                                # Step2: Initialising openai instance
# openai = OpenAI()

                                                # Step 3: Using chat completions API

# response = openai.chat.completions.create(model='gpt-5-nano', message= [{"role":"system", "content":"you are a helpful assistant"},
                                                                        # {"role":"user", "content":"how are you?"}])

                                                # Steo 4: getting response
# response.choices[0].message.content

# %%
# Understanding what happens behind - Basically openAPI makes a POST request to rest endpoint

# import requests

# api_key = 'api_key'

# headers = {"Authorization": f"Bearer{api_key}", "Content-Type":"application/json"}

# payload = {
#     "model": "qwen3.5:2b",
#     "messages":[
#         {"role":"system", "content": "You are an assistant name lili."},
#         {"role":"user", "content": "Who are you?"}
#     ]
# }

# response = requests.post(
#     # "https://api.openai.com/v1/chat/completions",
#     headers=headers,
#     json=payload
# )

# response

# %%
# And OpenAI decided to be kind: they said, hey, you can just use the same client library that we made for GPT. We'll allow you to specify a different endpoint URL and a different key, to use another provider.

# So you can use:

# gemini = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/", api_key="AIz....")
# gemini.chat.completions.create(...)
# And to be clear - even though OpenAI is in the code, we're only using this lightweight python client library to call the endpoint - there's no OpenAI model involved here.

# For example for gemini add your key to the .env file, being sure to Save the .env file after you change it:

# GOOGLE_API_KEY=AIz...

# GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

# load_dotenv(override=True)

# google_api_key = os.getenv("GOOGLE_API_KEY")

# gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

# response = gemini.chat.completions.create(model="gemini-2.5-flash-lite", messages=[{"role": "user", "content": "Tell me a fun fact"}])

# response.choices[0].message.content

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

response = ollama.chat.completions.create(model="qwen3.5:2b", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# "Here is the fun fact for you:\n\n**Did you know that a single drop of the Moon’s water is enough to power a tiny spaceship for a year?**\n\nIt turns out, the Moon is actually much cooler than it looks when you're looking at it in space. But you can't have it all. If you can't find the water, the moon is still a good place to learn about the rest of the universe!\n\nHave you ever wondered if there were any places on Earth without water? Or maybe you're wondering if the moon was the first place to develop life?\n\nAnyway, the moon is actually much cooler than it looks when you're looking at it in space. But you can't have it all.\n\n**The big secret:** The largest single living thing in the world is a **blue whale**. It can be up to 100 meters long and weigh more than a million pounds. That means its weight would be enough to cover the Earth's entire surface with just a few inches of water.\n\nSo, the biggest living thing on Earth is a tiny drop of water. But the biggest living thing 
# ...

# %%
# this literally took much time and got 600% of CPU usage so i am moving to huggingface, ie connecting huggingface and goggle colab so that my cpu is not used anymore....
